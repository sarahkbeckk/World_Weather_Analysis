# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vacay = pd.read_csv("total_cities.csv")
vacay.head(20)
# Out:
#     Unnamed: 0             City  Temperature  Humidity  Cloud Cover (%)  \
# 0            0        Kavaratti        82.33        60               31
# 1            1            Acarí        65.21        75               54
# 2            2         Khatanga        -4.09        99               96
# 3            3             Brae        51.62        88              100
# 4            4            Morón        70.50        76              100
# 5            5        Mahébourg        71.89        83               75
# 6            6         Thompson        24.96        93              100
# 7            7  Arraial do Cabo        70.97        78                1
# 8            8          Sonepur        71.37        74                0
# 9            9            Lagoa        62.51        69               37
# 10          10       Sangmélima        66.97        99              100
# 11          11        Busselton        62.47        57               68
# 12          12          Sørland        44.46        68              100
# 13          13           Neiafu        75.88        73               75
# 14          14            Ussel        49.51        96                3
# 15          15     Ponta do Sol        70.52        91               84
# 16          16       Kaitangata        50.34        90              100
# 17          17       São Filipe        78.24        77              100
# 18          18   Ribeira Grande        61.77        77               64
# 19          19        Killarney        55.08        85               71
#
#     Wind Speed       Log      Lat
# 0         9.69   72.6420  10.5669
# 1         4.36  -74.6158 -15.4311
# 2         3.87  102.5000  71.9667
# 3         9.08   -1.3530  60.3964
# 4        10.20  -58.6198 -34.6534
# 5        11.50   57.7000 -20.4081
# 6         6.91  -97.8558  55.7435
# 7         8.32  -42.0278 -22.9661
# 8         1.34   83.9167  20.8333
# 9        24.72  -27.9833  39.0500
# 10        2.17   11.9833   2.9333
# 11        8.08  115.3333 -33.6500
# 12        4.00   12.6934  67.6670
# 13        5.75 -173.9833 -18.6500
# 14        2.57    2.3167  45.5500
# 15        7.02  -17.1000  32.6667
# 16        6.80  169.8464 -46.2817
# 17        4.43  -24.4956  14.8961
# 18        1.99  -28.7000  38.5167
# 19       16.82   -9.5167  52.0500

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

vacay = remove(vacay, log):
    threshold = 90
    if(len(to_remove) > 90):
        vacay[log].replace(to_remove, np.nan)
    return df
# Out:
#   Input In [16]
#     vacay = remove(vacay, log):
#                               ^
# SyntaxError: invalid syntax

# %%
locations = vacay[['Log','Lat']]

humidity = vacay['Humidity']
 
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False,
                                 max_intensity=5,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# Input In [14], in <cell line: 7>()
#       3 humidity = vacay['Humidity']
#       5 fig = gmaps.figure()
# ----> 7 heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
#       8                                  dissipating=False,
#       9                                  max_intensity=5,
#      10                                  point_radius=1)
#      12 fig.add_layer(heat_layer)
#      13 fig
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gmaps/heatmap.py:269, in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     264 widget_args, is_weighted = _heatmap_options(
#     265     locations, weights, max_intensity, dissipating, point_radius,
#     266     opacity, gradient
#     267 )
#     268 if is_weighted:
# --> 269     return WeightedHeatmap(**widget_args)
#     270 else:
#     271     return Heatmap(**widget_args)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:412, in Widget.__init__(self, **kwargs)
#     410 """Public constructor"""
#     411 self._model_id = kwargs.pop('model_id', None)
# --> 412 super(Widget, self).__init__(**kwargs)
#     414 Widget._call_widget_constructed(self)
#     415 self.open()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py:1079, in HasTraits.__init__(self, *args, **kwargs)
#    1077 for key, value in kwargs.items():
#    1078     if self.has_trait(key):
# -> 1079         setattr(self, key, value)
#    1080     else:
#    1081         # passthrough args that don't set traits to super
#    1082         super_kwargs[key] = value
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py:606, in TraitType.__set__(self, obj, value)
#     604     raise TraitError('The "%s" trait is read-only.' % self.name)
#     605 else:
# --> 606     self.set(obj, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py:2651, in List.set(self, obj, value)
#    2649     return super().set(obj, [value])
#    2650 else:
# -> 2651     return super().set(obj, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py:580, in TraitType.set(self, obj, value)
#     579 def set(self, obj, value):
# --> 580     new_value = self._validate(obj, value)
#     581     try:
#     582         old_value = obj._trait_values[self.name]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py:612, in TraitType._validate(self, obj, value)
#     610     return value
#     611 if hasattr(self, 'validate'):
# --> 612     value = self.validate(obj, value)
#     613 if obj._cross_validation_lock is False:
#     614     value = self._cross_validate(obj, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gmaps/geotraitlets.py:27, in LocationArray.validate(self, obj, value)
#      25 for location in locations_as_list:
#      26     latitude, longitude = location
# ---> 27     _validate_latitude(latitude)
#      28     _validate_longitude(longitude)
#      29 return super(LocationArray, self).validate(obj, locations_as_list)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gmaps/geotraitlets.py:306, in _validate_latitude(latitude)
#     301     raise traitlets.TraitError(
#     302         '{} is not a valid latitude. '
#     303         'Latitudes must be floats'.format(latitude)
#     304     )
#     305 if not (-90.0 <= latitude <= 90.0):
# --> 306     raise InvalidPointException(
#     307         '{} is not a valid latitude. '
#     308         'Latitudes must lie between -90 and 90.'.format(latitude)
#     309     )
#
# InvalidPointException: 102.5 is not a valid latitude. Latitudes must lie between -90 and 90.

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
